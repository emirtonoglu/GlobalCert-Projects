# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
import numpy as np

# %%
df = pd.read_csv('Data.csv')
df = df.drop(['sl_no','ssc_b','hsc_b'], axis=1)
df
# Out:
#     gender  ssc_p  hsc_p     hsc_s  degree_p   degree_t workex  etest_p  \
# 0        M  67.00  91.00  Commerce     58.00   Sci&Tech     No     55.0
# 1        M  79.33  78.33   Science     77.48   Sci&Tech    Yes     86.5
# 2        M  65.00  68.00      Arts     64.00  Comm&Mgmt     No     75.0
# 3        M  56.00  52.00   Science     52.00   Sci&Tech     No     66.0
# 4        M  85.80  73.60  Commerce     73.30  Comm&Mgmt     No     96.8
# ..     ...    ...    ...       ...       ...        ...    ...      ...
# 210      M  80.60  82.00  Commerce     77.60  Comm&Mgmt     No     91.0
# 211      M  58.00  60.00   Science     72.00   Sci&Tech     No     74.0
# 212      M  67.00  67.00  Commerce     73.00  Comm&Mgmt    Yes     59.0
# 213      F  74.00  66.00  Commerce     58.00  Comm&Mgmt     No     70.0
# 214      M  62.00  58.00   Science     53.00  Comm&Mgmt     No     89.0
#
#     specialisation  mba_p      status    salary
# 0           Mkt&HR  58.80      Placed  270000.0
# 1          Mkt&Fin  66.28      Placed  200000.0
# 2          Mkt&Fin  57.80      Placed  250000.0
# 3           Mkt&HR  59.43  Not Placed       NaN
# 4          Mkt&Fin  55.50      Placed  425000.0
# ..             ...    ...         ...       ...
# 210        Mkt&Fin  74.49      Placed  400000.0
# 211        Mkt&Fin  53.62      Placed  275000.0
# 212        Mkt&Fin  69.72      Placed  295000.0
# 213         Mkt&HR  60.23      Placed  204000.0
# 214         Mkt&HR  60.22  Not Placed       NaN
#
# [215 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gender          215 non-null    object
#  1   ssc_p           215 non-null    float64
#  2   hsc_p           215 non-null    float64
#  3   hsc_s           215 non-null    object
#  4   degree_p        215 non-null    float64
#  5   degree_t        215 non-null    object
#  6   workex          215 non-null    object
#  7   etest_p         215 non-null    float64
#  8   specialisation  215 non-null    object
#  9   mba_p           215 non-null    float64
#  10  status          215 non-null    object
#  11  salary          148 non-null    float64
# dtypes: float64(6), object(6)
# memory usage: 20.3+ KB

# %%
df1 = df.groupby('status').get_group('Not Placed')
df1.info()
#All null salary values is connected to the status, if your status is not placed, your salary is null.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67 entries, 3 to 214
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gender          67 non-null     object
#  1   ssc_p           67 non-null     float64
#  2   hsc_p           67 non-null     float64
#  3   hsc_s           67 non-null     object
#  4   degree_p        67 non-null     float64
#  5   degree_t        67 non-null     object
#  6   workex          67 non-null     object
#  7   etest_p         67 non-null     float64
#  8   specialisation  67 non-null     object
#  9   mba_p           67 non-null     float64
#  10  status          67 non-null     object
#  11  salary          0 non-null      float64
# dtypes: float64(6), object(6)
# memory usage: 6.8+ KB

# %%
df.describe()
# Out:
#             ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000
# mean    67.303395   66.333163   66.370186   72.100558   62.278186
# std     10.827205   10.897509    7.358743   13.275956    5.833385
# min     40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     60.600000   60.900000   61.000000   60.000000   57.945000
# 50%     67.000000   65.000000   66.000000   71.000000   62.000000
# 75%     75.700000   73.000000   72.000000   83.500000   66.255000
# max     89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
sns.distplot(df.ssc_p,kde=False)
# Out:
# C:\Program Files\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ssc_p'>

# %%
bins=[0,55,70,80,100]
group=['Low','Average','High','Very High']
df['ssc_p_withgroups']=pd.cut(df['ssc_p'],bins,labels=group)

# %%
df
# Out:
#     gender  ssc_p  hsc_p     hsc_s  degree_p   degree_t workex  etest_p  \
# 0        M  67.00  91.00  Commerce     58.00   Sci&Tech     No     55.0
# 1        M  79.33  78.33   Science     77.48   Sci&Tech    Yes     86.5
# 2        M  65.00  68.00      Arts     64.00  Comm&Mgmt     No     75.0
# 3        M  56.00  52.00   Science     52.00   Sci&Tech     No     66.0
# 4        M  85.80  73.60  Commerce     73.30  Comm&Mgmt     No     96.8
# ..     ...    ...    ...       ...       ...        ...    ...      ...
# 210      M  80.60  82.00  Commerce     77.60  Comm&Mgmt     No     91.0
# 211      M  58.00  60.00   Science     72.00   Sci&Tech     No     74.0
# 212      M  67.00  67.00  Commerce     73.00  Comm&Mgmt    Yes     59.0
# 213      F  74.00  66.00  Commerce     58.00  Comm&Mgmt     No     70.0
# 214      M  62.00  58.00   Science     53.00  Comm&Mgmt     No     89.0
#
#     specialisation  mba_p      status    salary ssc_p_withgroups
# 0           Mkt&HR  58.80      Placed  270000.0          Average
# 1          Mkt&Fin  66.28      Placed  200000.0             High
# 2          Mkt&Fin  57.80      Placed  250000.0          Average
# 3           Mkt&HR  59.43  Not Placed       NaN          Average
# 4          Mkt&Fin  55.50      Placed  425000.0        Very High
# ..             ...    ...         ...       ...              ...
# 210        Mkt&Fin  74.49      Placed  400000.0        Very High
# 211        Mkt&Fin  53.62      Placed  275000.0          Average
# 212        Mkt&Fin  69.72      Placed  295000.0          Average
# 213         Mkt&HR  60.23      Placed  204000.0             High
# 214         Mkt&HR  60.22  Not Placed       NaN          Average
#
# [215 rows x 13 columns]

# %%
sns.distplot(df.hsc_p,kde=False)
# Out:
# C:\Program Files\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='hsc_p'>

# %%
bins=[0,55,70,85,100]
group=['Low','Average','High','Very High']
df['hsc_p_withgroups']=pd.cut(df['hsc_p'],bins,labels=group)

# %%
df
# Out:
#     gender  ssc_p  hsc_p     hsc_s  degree_p   degree_t workex  etest_p  \
# 0        M  67.00  91.00  Commerce     58.00   Sci&Tech     No     55.0
# 1        M  79.33  78.33   Science     77.48   Sci&Tech    Yes     86.5
# 2        M  65.00  68.00      Arts     64.00  Comm&Mgmt     No     75.0
# 3        M  56.00  52.00   Science     52.00   Sci&Tech     No     66.0
# 4        M  85.80  73.60  Commerce     73.30  Comm&Mgmt     No     96.8
# ..     ...    ...    ...       ...       ...        ...    ...      ...
# 210      M  80.60  82.00  Commerce     77.60  Comm&Mgmt     No     91.0
# 211      M  58.00  60.00   Science     72.00   Sci&Tech     No     74.0
# 212      M  67.00  67.00  Commerce     73.00  Comm&Mgmt    Yes     59.0
# 213      F  74.00  66.00  Commerce     58.00  Comm&Mgmt     No     70.0
# 214      M  62.00  58.00   Science     53.00  Comm&Mgmt     No     89.0
#
#     specialisation  mba_p      status    salary ssc_p_withgroups  \
# 0           Mkt&HR  58.80      Placed  270000.0          Average
# 1          Mkt&Fin  66.28      Placed  200000.0             High
# 2          Mkt&Fin  57.80      Placed  250000.0          Average
# 3           Mkt&HR  59.43  Not Placed       NaN          Average
# 4          Mkt&Fin  55.50      Placed  425000.0        Very High
# ..             ...    ...         ...       ...              ...
# 210        Mkt&Fin  74.49      Placed  400000.0        Very High
# 211        Mkt&Fin  53.62      Placed  275000.0          Average
# 212        Mkt&Fin  69.72      Placed  295000.0          Average
# 213         Mkt&HR  60.23      Placed  204000.0             High
# 214         Mkt&HR  60.22  Not Placed       NaN          Average
#
#     hsc_p_withgroups
# 0          Very High
# 1               High
# 2            Average
# 3                Low
# 4               High
# ..               ...
# 210             High
# 211          Average
# 212          Average
# 213          Average
# 214          Average
#
# [215 rows x 14 columns]

# %%
sns.distplot(df.degree_p,kde=False)
# Out:
# C:\Program Files\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='degree_p'>

# %%
bins=[0,60,70,80,100]
group=['Low','Average','High','Very High']
df['degree_p_withgroups']=pd.cut(df['degree_p'],bins,labels=group)

# %%
df
# Out:
#     gender  ssc_p  hsc_p     hsc_s  degree_p   degree_t workex  etest_p  \
# 0        M  67.00  91.00  Commerce     58.00   Sci&Tech     No     55.0
# 1        M  79.33  78.33   Science     77.48   Sci&Tech    Yes     86.5
# 2        M  65.00  68.00      Arts     64.00  Comm&Mgmt     No     75.0
# 3        M  56.00  52.00   Science     52.00   Sci&Tech     No     66.0
# 4        M  85.80  73.60  Commerce     73.30  Comm&Mgmt     No     96.8
# ..     ...    ...    ...       ...       ...        ...    ...      ...
# 210      M  80.60  82.00  Commerce     77.60  Comm&Mgmt     No     91.0
# 211      M  58.00  60.00   Science     72.00   Sci&Tech     No     74.0
# 212      M  67.00  67.00  Commerce     73.00  Comm&Mgmt    Yes     59.0
# 213      F  74.00  66.00  Commerce     58.00  Comm&Mgmt     No     70.0
# 214      M  62.00  58.00   Science     53.00  Comm&Mgmt     No     89.0
#
#     specialisation  mba_p      status    salary ssc_p_withgroups  \
# 0           Mkt&HR  58.80      Placed  270000.0          Average
# 1          Mkt&Fin  66.28      Placed  200000.0             High
# 2          Mkt&Fin  57.80      Placed  250000.0          Average
# 3           Mkt&HR  59.43  Not Placed       NaN          Average
# 4          Mkt&Fin  55.50      Placed  425000.0        Very High
# ..             ...    ...         ...       ...              ...
# 210        Mkt&Fin  74.49      Placed  400000.0        Very High
# 211        Mkt&Fin  53.62      Placed  275000.0          Average
# 212        Mkt&Fin  69.72      Placed  295000.0          Average
# 213         Mkt&HR  60.23      Placed  204000.0             High
# 214         Mkt&HR  60.22  Not Placed       NaN          Average
#
#     hsc_p_withgroups degree_p_withgroups
# 0          Very High                 Low
# 1               High                High
# 2            Average             Average
# 3                Low                 Low
# 4               High                High
# ..               ...                 ...
# 210             High                High
# 211          Average                High
# 212          Average                High
# 213          Average                 Low
# 214          Average                 Low
#
# [215 rows x 15 columns]

# %%
sns.distplot(df.etest_p,kde=False)
# Out:
# C:\Program Files\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='etest_p'>

# %%
bins=[0,60,70,90,100]
group=['Low','Average','High','Very High']
df['etest_p_withgroups']=pd.cut(df['etest_p'],bins,labels=group)

# %%
df
# Out:
#     gender  ssc_p  hsc_p     hsc_s  degree_p   degree_t workex  etest_p  \
# 0        M  67.00  91.00  Commerce     58.00   Sci&Tech     No     55.0
# 1        M  79.33  78.33   Science     77.48   Sci&Tech    Yes     86.5
# 2        M  65.00  68.00      Arts     64.00  Comm&Mgmt     No     75.0
# 3        M  56.00  52.00   Science     52.00   Sci&Tech     No     66.0
# 4        M  85.80  73.60  Commerce     73.30  Comm&Mgmt     No     96.8
# ..     ...    ...    ...       ...       ...        ...    ...      ...
# 210      M  80.60  82.00  Commerce     77.60  Comm&Mgmt     No     91.0
# 211      M  58.00  60.00   Science     72.00   Sci&Tech     No     74.0
# 212      M  67.00  67.00  Commerce     73.00  Comm&Mgmt    Yes     59.0
# 213      F  74.00  66.00  Commerce     58.00  Comm&Mgmt     No     70.0
# 214      M  62.00  58.00   Science     53.00  Comm&Mgmt     No     89.0
#
#     specialisation  mba_p      status    salary ssc_p_withgroups  \
# 0           Mkt&HR  58.80      Placed  270000.0          Average
# 1          Mkt&Fin  66.28      Placed  200000.0             High
# 2          Mkt&Fin  57.80      Placed  250000.0          Average
# 3           Mkt&HR  59.43  Not Placed       NaN          Average
# 4          Mkt&Fin  55.50      Placed  425000.0        Very High
# ..             ...    ...         ...       ...              ...
# 210        Mkt&Fin  74.49      Placed  400000.0        Very High
# 211        Mkt&Fin  53.62      Placed  275000.0          Average
# 212        Mkt&Fin  69.72      Placed  295000.0          Average
# 213         Mkt&HR  60.23      Placed  204000.0             High
# 214         Mkt&HR  60.22  Not Placed       NaN          Average
#
#     hsc_p_withgroups degree_p_withgroups etest_p_withgroups
# 0          Very High                 Low                Low
# 1               High                High               High
# 2            Average             Average               High
# 3                Low                 Low            Average
# 4               High                High          Very High
# ..               ...                 ...                ...
# 210             High                High          Very High
# 211          Average                High               High
# 212          Average                High                Low
# 213          Average                 Low            Average
# 214          Average                 Low               High
#
# [215 rows x 16 columns]

# %%
sns.distplot(df.mba_p,kde=False)
# Out:
# C:\Program Files\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='mba_p'>

# %%
bins=[0,57,65,70,100]
group=['Low','Average','High','Very High']
df['mba_p_withgroups']=pd.cut(df['mba_p'],bins,labels=group)

# %%
df
# Out:
#     gender  ssc_p  hsc_p     hsc_s  degree_p   degree_t workex  etest_p  \
# 0        M  67.00  91.00  Commerce     58.00   Sci&Tech     No     55.0
# 1        M  79.33  78.33   Science     77.48   Sci&Tech    Yes     86.5
# 2        M  65.00  68.00      Arts     64.00  Comm&Mgmt     No     75.0
# 3        M  56.00  52.00   Science     52.00   Sci&Tech     No     66.0
# 4        M  85.80  73.60  Commerce     73.30  Comm&Mgmt     No     96.8
# ..     ...    ...    ...       ...       ...        ...    ...      ...
# 210      M  80.60  82.00  Commerce     77.60  Comm&Mgmt     No     91.0
# 211      M  58.00  60.00   Science     72.00   Sci&Tech     No     74.0
# 212      M  67.00  67.00  Commerce     73.00  Comm&Mgmt    Yes     59.0
# 213      F  74.00  66.00  Commerce     58.00  Comm&Mgmt     No     70.0
# 214      M  62.00  58.00   Science     53.00  Comm&Mgmt     No     89.0
#
#     specialisation  mba_p      status    salary ssc_p_withgroups  \
# 0           Mkt&HR  58.80      Placed  270000.0          Average
# 1          Mkt&Fin  66.28      Placed  200000.0             High
# 2          Mkt&Fin  57.80      Placed  250000.0          Average
# 3           Mkt&HR  59.43  Not Placed       NaN          Average
# 4          Mkt&Fin  55.50      Placed  425000.0        Very High
# ..             ...    ...         ...       ...              ...
# 210        Mkt&Fin  74.49      Placed  400000.0        Very High
# 211        Mkt&Fin  53.62      Placed  275000.0          Average
# 212        Mkt&Fin  69.72      Placed  295000.0          Average
# 213         Mkt&HR  60.23      Placed  204000.0             High
# 214         Mkt&HR  60.22  Not Placed       NaN          Average
#
#     hsc_p_withgroups degree_p_withgroups etest_p_withgroups mba_p_withgroups
# 0          Very High                 Low                Low          Average
# 1               High                High               High             High
# 2            Average             Average               High          Average
# 3                Low                 Low            Average          Average
# 4               High                High          Very High              Low
# ..               ...                 ...                ...              ...
# 210             High                High          Very High        Very High
# 211          Average                High               High              Low
# 212          Average                High                Low             High
# 213          Average                 Low            Average          Average
# 214          Average                 Low               High          Average
#
# [215 rows x 17 columns]

# %%
sns.distplot(df.salary,kde=False)
# Out:
# C:\Program Files\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='salary'>

# %%
df['salary_log'] =np.log(df['salary'])

# %%
sns.distplot(df.salary_log,kde=False)
# Out:
# C:\Program Files\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='salary_log'>

# %%
df["salary_log"]=df["salary_log"].fillna(0, inplace = False)
bins=[-1,12,12.38,12.61,12.99,100]
group=['Not Hired','Low','Average','High','Very High']
df['salary_with_groups']=pd.cut(df['salary_log'],bins,labels=group)

# %% [markdown]
# - Not hired = 0
# - Low = 200000 - 240000
# - Average = 240000 - 300000
# - High = 300000 - 440000
# - Very High = More Than 440000

# %%
df['salary_with_groups'].value_counts()
# Out:
# Average      69
# Not Hired    67
# High         43
# Low          29
# Very High     7
# Name: salary_with_groups, dtype: int64

# %%
df
# Out:
#     gender  ssc_p  hsc_p     hsc_s  degree_p   degree_t workex  etest_p  \
# 0        M  67.00  91.00  Commerce     58.00   Sci&Tech     No     55.0
# 1        M  79.33  78.33   Science     77.48   Sci&Tech    Yes     86.5
# 2        M  65.00  68.00      Arts     64.00  Comm&Mgmt     No     75.0
# 3        M  56.00  52.00   Science     52.00   Sci&Tech     No     66.0
# 4        M  85.80  73.60  Commerce     73.30  Comm&Mgmt     No     96.8
# ..     ...    ...    ...       ...       ...        ...    ...      ...
# 210      M  80.60  82.00  Commerce     77.60  Comm&Mgmt     No     91.0
# 211      M  58.00  60.00   Science     72.00   Sci&Tech     No     74.0
# 212      M  67.00  67.00  Commerce     73.00  Comm&Mgmt    Yes     59.0
# 213      F  74.00  66.00  Commerce     58.00  Comm&Mgmt     No     70.0
# 214      M  62.00  58.00   Science     53.00  Comm&Mgmt     No     89.0
#
#     specialisation  mba_p      status    salary ssc_p_withgroups  \
# 0           Mkt&HR  58.80      Placed  270000.0          Average
# 1          Mkt&Fin  66.28      Placed  200000.0             High
# 2          Mkt&Fin  57.80      Placed  250000.0          Average
# 3           Mkt&HR  59.43  Not Placed       NaN          Average
# 4          Mkt&Fin  55.50      Placed  425000.0        Very High
# ..             ...    ...         ...       ...              ...
# 210        Mkt&Fin  74.49      Placed  400000.0        Very High
# 211        Mkt&Fin  53.62      Placed  275000.0          Average
# 212        Mkt&Fin  69.72      Placed  295000.0          Average
# 213         Mkt&HR  60.23      Placed  204000.0             High
# 214         Mkt&HR  60.22  Not Placed       NaN          Average
#
#     hsc_p_withgroups degree_p_withgroups etest_p_withgroups mba_p_withgroups  \
# 0          Very High                 Low                Low          Average
# 1               High                High               High             High
# 2            Average             Average               High          Average
# 3                Low                 Low            Average          Average
# 4               High                High          Very High              Low
# ..               ...                 ...                ...              ...
# 210             High                High          Very High        Very High
# 211          Average                High               High              Low
# 212          Average                High                Low             High
# 213          Average                 Low            Average          Average
# 214          Average                 Low               High          Average
#
#      salary_log salary_with_groups
# 0     12.506177            Average
# 1     12.206073                Low
# 2     12.429216            Average
# 3      0.000000          Not Hired
# 4     12.959844               High
# ..          ...                ...
# 210   12.899220               High
# 211   12.524526            Average
# 212   12.594731            Average
# 213   12.225875                Low
# 214    0.000000          Not Hired
#
# [215 rows x 19 columns]

# %%
cred = pd.crosstab(df['etest_p_withgroups'], df['salary_with_groups'])
print(cred)
cred.plot(kind='bar', stacked=True, color=['blue','red','yellow','green','purple'],figsize=(10,10), grid=False)
# Out:
# salary_with_groups  Not Hired  Low  Average  High  Very High
# etest_p_withgroups
# Low                        21    6       25     6          1
# Average                    17    9       18     2          2
# High                       25   13       17    24          4
# Very High                   4    1        9    11          0
# <AxesSubplot:xlabel='etest_p_withgroups'>

# %%
sns.boxplot(x = 'specialisation', y = 'salary', data = df)
# Out:
# <AxesSubplot:xlabel='specialisation', ylabel='salary'>

# %%
cred = pd.crosstab(df['specialisation'], df['salary_with_groups'])
print(cred)
# Out:
# salary_with_groups  Not Hired  Low  Average  High  Very High
# specialisation
# Mkt&Fin                    25   18       41    30          6
# Mkt&HR                     42   11       28    13          1

# %%
cred = pd.crosstab(df['mba_p_withgroups'], df['salary_with_groups'])
print(cred)
cred.plot(kind='bar', stacked=True, color=['blue','red','yellow','green','purple'],figsize=(10,10), grid=False)
# Out:
# salary_with_groups  Not Hired  Low  Average  High  Very High
# mba_p_withgroups
# Low                        13    5       18     7          0
# Average                    35   14       31    20          3
# High                       14    7       15     7          2
# Very High                   5    3        5     9          2
# <AxesSubplot:xlabel='mba_p_withgroups'>

# %%
sns.boxplot(x = 'workex', y = 'salary', data = df)
# Out:
# <AxesSubplot:xlabel='workex', ylabel='salary'>

# %%
cred = pd.crosstab(df['workex'], df['salary_with_groups'])
print(cred)
# Out:
# salary_with_groups  Not Hired  Low  Average  High  Very High
# workex
# No                         57   19       39    24          2
# Yes                        10   10       30    19          5

# %%
train = df.drop(['salary','salary_log','ssc_p','hsc_p','degree_p','etest_p','mba_p','salary','salary_log'],axis=1)
x = train.drop('salary_with_groups',1)
y = train.salary_with_groups
train
# Out:
# C:\Users\Emir Tonoğlu\AppData\Local\Temp\ipykernel_10496\85467898.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x = train.drop('salary_with_groups',1)
#     gender     hsc_s   degree_t workex specialisation      status  \
# 0        M  Commerce   Sci&Tech     No         Mkt&HR      Placed
# 1        M   Science   Sci&Tech    Yes        Mkt&Fin      Placed
# 2        M      Arts  Comm&Mgmt     No        Mkt&Fin      Placed
# 3        M   Science   Sci&Tech     No         Mkt&HR  Not Placed
# 4        M  Commerce  Comm&Mgmt     No        Mkt&Fin      Placed
# ..     ...       ...        ...    ...            ...         ...
# 210      M  Commerce  Comm&Mgmt     No        Mkt&Fin      Placed
# 211      M   Science   Sci&Tech     No        Mkt&Fin      Placed
# 212      M  Commerce  Comm&Mgmt    Yes        Mkt&Fin      Placed
# 213      F  Commerce  Comm&Mgmt     No         Mkt&HR      Placed
# 214      M   Science  Comm&Mgmt     No         Mkt&HR  Not Placed
#
#     ssc_p_withgroups hsc_p_withgroups degree_p_withgroups etest_p_withgroups  \
# 0            Average        Very High                 Low                Low
# 1               High             High                High               High
# 2            Average          Average             Average               High
# 3            Average              Low                 Low            Average
# 4          Very High             High                High          Very High
# ..               ...              ...                 ...                ...
# 210        Very High             High                High          Very High
# 211          Average          Average                High               High
# 212          Average          Average                High                Low
# 213             High          Average                 Low            Average
# 214          Average          Average                 Low               High
#
#     mba_p_withgroups salary_with_groups
# 0            Average            Average
# 1               High                Low
# 2            Average            Average
# 3            Average          Not Hired
# 4                Low               High
# ..               ...                ...
# 210        Very High               High
# 211              Low            Average
# 212             High            Average
# 213          Average                Low
# 214          Average          Not Hired
#
# [215 rows x 12 columns]

# %%
x = pd.get_dummies(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_cv, y_train, y_cv = train_test_split(x,y, test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
model = LogisticRegression(random_state = 1)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=1)

# %%
pred_cv = model.predict(x_cv)
accuracy_score(y_cv,pred_cv)
# Out:
# 0.6153846153846154

# %%
from sklearn.metrics import confusion_matrix
cnf=confusion_matrix(y_cv, pred_cv)
cnf
# Out:
# array([[16,  3,  2,  0,  0],
#        [ 8,  6,  1,  0,  0],
#        [ 8,  0,  2,  0,  0],
#        [ 0,  0,  0, 16,  0],
#        [ 2,  1,  0,  0,  0]], dtype=int64)

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier(random_state=1)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
pred_cv = model.predict(x_cv)
accuracy_score(y_cv,pred_cv)
# Out:
# 0.5076923076923077

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(random_state=1, max_depth=10)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10, random_state=1)

# %%
pred_cv = model.predict(x_cv)
accuracy_score(y_cv,pred_cv)
# Out:
# 0.5846153846153846
